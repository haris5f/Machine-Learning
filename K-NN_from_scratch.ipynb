# %% [markdown]
# # CS535/EE514 Machine Learning - Spring 2022 - PA2

# %% [markdown]
# ## Instructions
#
# *   Submit your code both as notebook file (.ipynb) and python script (.py) on LMS. The name of both files should be 'RollNo_PA2'. Failing to submit any one of them will result in the reduction of marks.
# *  All the cells must be run once before submission and should be displaying the results(graphs/plots etc). If output of the cells is not being displayed, marks will be dedcuted.
# *   The code MUST be implemented independently. Any plagiarism or cheating of work from others or the internet will be immediately referred to the DC.
# * 10% penalty per day for 3 days after due date. No submissions will be accepted
# after that.
# * Use procedural programming style and comment your code properly.
# * **Deadline to submit this assignment is 21/02/2022.**

# %% [markdown]
# ## Part 1: Implement K-NN classifier from scratch
# The goal of this assignment is to get you familiar with k-NN classification and to give hands on experience of basic python tools and libraries which will be used in implementing the algorithm.
# You are not allowed to use scikit-learn or any other machine learning toolkit for this part.
# You have to implement your own k-NN classifier from scratch. You may use Pandas, NumPy, Matplotlib and other standard python libraries.

# %%
# making all necessary imports here. You can make your own imports here if needed.
import glob
import cv2
import os
from google.colab import drive
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.datasets import make_blobs
from sklearn.model_selection import GridSearchCV
#
from statistics import mode

# %%
# Downloading Dataset
# !gdown --id 1ZPLfYxdXs856KsjcBgG2QGjjr6ayPwVj
# !unzip "Apparel_Dataset.zip"
# Out:
# Access denied with the following error:
#
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?id=1ZPLfYxdXs856KsjcBgG2QGjjr6ayPwVj
#
# Archive:  Apparel_Dataset.zip
#    creating: Apparel_Dataset/
#    creating: Apparel_Dataset/Test Data/
#    creating: Apparel_Dataset/Test Data/dress/
#   inflating: Apparel_Dataset/Test Data/dress/038098f911bf30451c109d19870668c39dcf0c11.jpg
#   inflating: Apparel_Dataset/Test Data/dress/06130b80c92914dcccb56634594b4aeab7db5944.jpg
#   inflating: Apparel_Dataset/Test Data/dress/06677e9166ce249cbe6f7cbf6ea4fae6386a1c3e.jpg
#   inflating: Apparel_Dataset/Test Data/dress/1157ce46a9d5b369f2be2cf80350dad7a2bfa144.jpg
#   inflating: Apparel_Dataset/Test Data/dress/12197cde1e9ad94ca7fdaa1bca5d8dd60868155b.jpg
#   inflating: Apparel_Dataset/Test Data/dress/1274e149dccaa0631c4cb133bf66aa0b3ae961c3.jpg
#   inflating: Apparel_Dataset/Test Data/dress/12799e21492de89cbbde82d66cb46d267a7706d5.jpg
#   inflating: Apparel_Dataset/Test Data/dress/1369f6c8fcf9ea05e3b5733929197ca233fc5296.jpg
#   inflating: Apparel_Dataset/Test Data/dress/14144f925ffebd655a6c40315ffc3751a98bfee5.jpg
#   inflating: Apparel_Dataset/Test Data/dress/18498d91364222ea5c1c42cb3329c1ff3bf11325.jpg
#   inflating: Apparel_Dataset/Test Data/dress/1870f77ade6b8f2587673ebad1137bfcdb8c85ce.jpg
#   inflating: Apparel_Dataset/Test Data/dress/2151c6dc9e32c64bb470667210014870a2f80628.jpg
#   inflating: Apparel_Dataset/Test Data/dress/24454f67b060d8f911371c86b71b3e5b3e74abed.jpg
#   inflating: Apparel_Dataset/Test Data/dress/2524bb5b396db645115f7480ba71d81bc855c5dc.jpg
#   inflating: Apparel_Dataset/Test Data/dress/2527a55318df3d1de77082f23c038f87476dcde8.jpg
#   inflating: Apparel_Dataset/Test Data/dress/2609b743082c39d55f6f725266ad7a36da00ec9d.jpg
#   inflating: Apparel_Dataset/Test Data/dress/2635a7e067debb724f7d8067592d07d28673d0fc.jpg
#   inflating: Apparel_Dataset/Test Data/dress/29903c3ac595382ae2f0610af580feca1c5bb4b3.jpg
#   inflating: Apparel_Dataset/Test Data/dress/31040b726b9c2fb2866960c0b2e1d938aecad935.jpg
#   inflating: Apparel_Dataset/Test Data/dress/32665e1a433f0d2340b36e28ca9ead82e876db80.jpg
#   inflating: Apparel_Dataset/Test Data/dress/32918e2db7745150e06671394c7465ee86a85f31.jpg
#   inflating: Apparel_Dataset/Test Data/dress/3365cab83ea4da9d1a42b13f44b2efb3d0a6b0a7.jpg
#   inflating: Apparel_Dataset/Test Data/dress/3422d6d78e0a90e58bf9d1afa10cd601871cf9ea.jpg
#   inflating: Apparel_Dataset/Test Data/dress/35181cd8d33e33a5d6e812a4304ff19d7d79ae77.jpg
#   inflating: Apparel_Dataset/Test Data/dress/4070b4440edf8ee5ddac6356ec0655088e68cc56.jpg
#   inflating: Apparel_Dataset/Test Data/dress/433a36e22273b3c314b57aa72c42270fbef8bf53.jpg
#   inflating: Apparel_Dataset/Test Data/dress/4384a199caf1b29ae01f536f4e02b0d310bd735e.jpg
#   inflating: Apparel_Dataset/Test Data/dress/441f7cce7e2576b43860559ec267e3e11772c7b3.jpg
#   inflating: Apparel_Dataset/Test Data/dress/4500ca65c5eb8d42782fc4f4a722109a26d40933.jpg
#   inflating: Apparel_Dataset/Test Data/dress/4672e1d659f79717696496ad96938726b0133da5.jpg
#   inflating: Apparel_Dataset/Test Data/dress/476d6bf845deadb096a80811ccd8168dbcf00af3.jpg
#   inflating: Apparel_Dataset/Test Data/dress/4833b35255eff1f208b4d10d6c21ffc2ef30183a.jpg
#   inflating: Apparel_Dataset/Test Data/dress/505ac435719a4199fa9481d493d621e0949a3e61.jpg
#   inflating: Apparel_Dataset/Test Data/dress/519b4f8d50500c2e032305892f05bea7ec5fdb80.jpg
#   inflating: Apparel_Dataset/Test Data/dress/527dc8893cb2543b24d8d211ea5efe423090bbcb.jpg
#   inflating: Apparel_Dataset/Test Data/dress/538e5bcc3bd7476dda70b4099cc1c63d07c3bde9.jpg
#   inflating: Apparel_Dataset/Test Data/dress/5489d03cad1c9e0eda8f1c9927222f37b6d1e450.jpg
#   inflating: Apparel_Dataset/Test Data/dress/5525cb64df539dff692de1773956b12a630ad19e.jpg
#   inflating: Apparel_Dataset/Test Data/dress/559e43dc6493b547100e00df4ce19e1f4bd0e842.jpg
#   inflating: Apparel_Dataset/Test Data/dress/5728c4567e6e414963f54eb98af3a3254a53913c.jpg
#   inflating: Apparel_Dataset/Test Data/dress/582bf1841627e8b966abda9702033e4fa38ab0fe.jpg
#   inflating: Apparel_Dataset/Test Data/dress/5928a0b349675bc3ff947b267373070cdb7d7fd9.jpg
#   inflating: Apparel_Dataset/Test Data/dress/6016dc3b26d645de68bddc0e87711dfbf7a1d191.jpg
#   inflating: Apparel_Dataset/Test Data/dress/6031e53fc62e6e2dd04cc19c8224213122776752.jpg
#   inflating: Apparel_Dataset/Test Data/dress/6187c155957cd443b7c320cbdd538a301592e9d6.jpg
#   inflating: Apparel_Dataset/Test Data/dress/640db9308ed82144cccf8f36b2bc4b4638dbd1b7.jpg
#   inflating: Apparel_Dataset/Test Data/dress/642aa9f0aaac259dfd9c6211a1da563e58a7cad2.jpg
#   inflating: Apparel_Dataset/Test Data/dress/6672de64c18ffe15ee8c54df858f27bb006dfe4f.jpg
#   inflating: Apparel_Dataset/Test Data/dress/678f81a1dfa1aa4ea3a505c3f5e24e75c416e40b.jpg
#   inflating: Apparel_Dataset/Test Data/dress/6794b21066bfcb0a3e1fb025b3831c05302ea948.jpg
#   inflating: Apparel_Dataset/Test Data/dress/6837d108221c3e75fe44bf4a6c13f5b2c7f728b8.jpg
#   inflating: Apparel_Dataset/Test Data/dress/688e5484a57aae6d8b7e77f61fb86da5dcab1706.jpg
#   inflating: Apparel_Dataset/Test Data/dress/690de7031b08f48a5264105cd3c8c943ff5d1e5d.jpg
#   inflating: Apparel_Dataset/Test Data/dress/6966d8ab7db0ffd83292aba5066a780c5b519b4a.jpg
#   inflating: Apparel_Dataset/Test Data/dress/7131f387d71fcd2830d224dc90b58a13fe5ee480.jpg
#   inflating: Apparel_Dataset/Test Data/dress/725bb353c6ab8f2663b779565356d8ed0f0d1321.jpg
#   inflating: Apparel_Dataset/Test Data/dress/735dec8605d2aab4688f54bbed6a8e949836de58.jpg
#   inflating: Apparel_Dataset/Test Data/dress/736c212b07624764d16850e24cb5f9fe2df738f1.jpg
#   inflating: Apparel_Dataset/Test Data/dress/739af7cc58dcbac272a3e6fca1c613f035c48e73.jpg
#   inflating: Apparel_Dataset/Test Data/dress/743e8a4edef1e7fec35080a0d357417530d2d46a.jpg
#   inflating: Apparel_Dataset/Test Data/dress/7493e8ef3afdeec927a187e639a2dd32a832eb2c.jpg
#   inflating: Apparel_Dataset/Test Data/dress/7563c5d9fa6e038ada5a159c010ea16817d647bf.jpg
#   inflating: Apparel_Dataset/Test Data/dress/7651d7c94f66e724a3a3fe18bc7e824b7036e32a.jpg
#   inflating: Apparel_Dataset/Test Data/dress/768e96eceba66a0479e3acc431a15de28efcf178.jpg
#   inflating: Apparel_Dataset/Test Data/dress/769e82ec9c487f4c3470e60fd2d413dc7677d185.jpg
#   inflating: Apparel_Dataset/Test Data/dress/793ebcd57b9e5d36f4ff2b2603311f12081a4ab8.jpg
#   inflating: Apparel_Dataset/Test Data/dress/8127c84e417e749c26e5b70155b1534dbab62e8d.jpg
#   inflating: Apparel_Dataset/Test Data/dress/8142de7de3754bcc69609c3346ac5884aaaaca02.jpg
#   inflating: Apparel_Dataset/Test Data/dress/828f09e60067ab62cef31ddd50681166a5f3bed7.jpg
#   inflating: Apparel_Dataset/Test Data/dress/8333aa8ab1bf243304cf7a76c33dcfe9a956d2dc.jpg
#   inflating: Apparel_Dataset/Test Data/dress/8343f3e26ccb9fd3cabc8f12e916c05feb21e2ab.jpg
#   inflating: Apparel_Dataset/Test Data/dress/870dc5324dd92dc579df7efa9d3a08759978b9ff.jpg
#   inflating: Apparel_Dataset/Test Data/dress/878bea5e0d3a5479583f9664803c7cf4db2168d7.jpg
#   inflating: Apparel_Dataset/Test Data/dress/882b5529866056594a72bbd5c6e130a88f5fcc7b.jpg
#   inflating: Apparel_Dataset/Test Data/dress/891a1e37f6e3c814c6010c5d15bdbe857511fe1c.jpg
#   inflating: Apparel_Dataset/Test Data/dress/8965c02be370075a35a370cd3d624f4659424534.jpg
#   inflating: Apparel_Dataset/Test Data/dress/9065d622a1d81a31d6265c4f7db01a96a32267df.jpg
#   inflating: Apparel_Dataset/Test Data/dress/9108fbd65d1008f48edc34966e3ec8fae7a9f2d0.jpg
#   inflating: Apparel_Dataset/Test Data/dress/911adc6dfca5602b13517d58e8793912a87380fd.jpg
#   inflating: Apparel_Dataset/Test Data/dress/912eb01aa9a41665a3153c74e9901d18bcad2810.jpg
#   inflating: Apparel_Dataset/Test Data/dress/9130da71c1b7aee57d8b14dce18a388550f3a197.jpg
#   inflating: Apparel_Dataset/Test Data/dress/916aa9ef8557dbe7c22df84e18a1986763631bc5.jpg
#   inflating: Apparel_Dataset/Test Data/dress/9441a104de29979470be5ae3ba1a13274d1a0032.jpg
#   inflating: Apparel_Dataset/Test Data/dress/947a981377eb6ddd85436eb12084700e7338cb4e.jpg
#   inflating: Apparel_Dataset/Test Data/dress/9567cb75efeaf3cc2b6d55ed52466f8d34df78d3.jpg
#   inflating: Apparel_Dataset/Test Data/dress/956aa85de5126891236177d293760ae1b6106f54.jpg
#   inflating: Apparel_Dataset/Test Data/dress/977d24b314a1e22c9ef51f6b5cc8fb02b0e9a504.jpg
#   inflating: Apparel_Dataset/Test Data/dress/991ab6dcfa1ad917b4eb4292b2fb424334dd6c82.jpg
#   inflating: Apparel_Dataset/Test Data/dress/9928a8fee5eeb878a9e55b459026c495732711c3.jpg
#   inflating: Apparel_Dataset/Test Data/dress/9974d63c308778474f5ef5c536634c8cc279a9c7.jpg
#    creating: Apparel_Dataset/Test Data/pants/
#   inflating: Apparel_Dataset/Test Data/pants/00a2c27ab296e6c2f7220f38c68ef3d11bdd25bd.jpg
#   inflating: Apparel_Dataset/Test Data/pants/00b5c1713285d82ecc9488eab3e7640e35ba5d9e.jpg
#   inflating: Apparel_Dataset/Test Data/pants/03a4118a57838a3a55013d1955322e3de37605cb.jpg
#   inflating: Apparel_Dataset/Test Data/pants/04ace5dd28f43ac3d7aee087a164a8e24227ee05.jpg
#   inflating: Apparel_Dataset/Test Data/pants/04bec730ec87ffd1105d271c89f18c7432d1cedc.jpg
#   inflating: Apparel_Dataset/Test Data/pants/05e2e744dd895cf059c66ea569e85c2eda6df1f6.jpg
#   inflating: Apparel_Dataset/Test Data/pants/06f56313385c29b83a18d335c625a2989d8c1626.jpg
#   inflating: Apparel_Dataset/Test Data/pants/06f6e2c292efc41176a6e19952376c9bab530521.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0a6a6e9ab2ba79a98bab107c3e81da7e115f4500.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0be7a069a72c04911171c47b213ff437df940bc4.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0c0422a0e054c028af1ed7efa64482ef5db6d544.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0c106ff2bc1999aa064d4cf211462dc60918bea5.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0c2a3939cd72953fd76258036d419f7fc8acae5e.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0c4597635ed9eb4cee73f2bd4e1c3dc30c93dd2f.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0c897fb8f3f8c95f51d1708d2ec7b84c19773721.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0c9f6894c815417c674705d16ae4b0133275260c.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0ce3f0ec51fa7988c53a57cefe926b51bacf187c.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0cf07392c9e6bacc99bdaa4c88c793d554f58321.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0cffd161f5bc66e926f2c9ff2af2cc46e1908183.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0d0089863be79afb85bb00a45ff6ba1af84d4800.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0d5423904049c4f8fd8e3a61079c8d98f72d83da.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0d7069b6266bdd291bbfcc3751d08b6a667de03e.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0db6523c18767d57801773be2dfc28d12102dd19.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0dcfc51b445ed8dc33751006c79429a9cabb9f2e.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0e1c005860ec3a58da8eb10a8f5b92ee0b0653ab.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0e46d96fa7b070d17ccbcf4a3a4581217d783291.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0e6498242a71050a7ae83ecc852969f68aa1eb23.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0e6e2d7f161dda606f0e2c30c26627007b6ee5be.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0e9675e572217c6c31c1b3640b295a1051873aa7.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0ec92adce224149371ac799ec64da3bf064c13fe.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0ece1ab0e3e001827dfb5728443f202d6d16caa7.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0ece68d17000b31ff47b1a295ff3bf689a123ad9.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0ed5b84ac24621a1d26803c3b7a4b5babf959f37.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0f1bb5d0d996ea755bfe6a463ff5b6ceb5634f7f.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0f8eb4509cea01f9656e8b31e3af0d29852cd90e.jpg
#   inflating: Apparel_Dataset/Test Data/pants/0fda8c5dd05e2e6973eaa9d29633164541c1e290.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1a0da5cbde1c81e33696cbb4ea4a12682ce73608.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1a1c08ffe314723db79a8f0005bf9e4fbb4ae4a5.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1a5eb6fdd566f4e1c41ab2971e4762bf69290d01.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1aa25b31c428bd5984f6582cee2e1668fd4247bd.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1abc5df789180a8691a43218c1e43b9f7e0b2bf1.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1ae40425092075e53d45c75d7ecb17e49ad9209a.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1b265db771e0385a92eee975ffbbbd281e02307f.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1b673260cbaa3b582914579afb002d9bfc3939b1.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1be5496e3df9b8af55ca1cf063752d0e3096ff80.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1c7854967c58c4dc0e133f8f43411d47df391d85.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1c78ecd6c84aa431e7ee9a56e9933d6316e399d9.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1c84c7697dfab421ba85972c6e8a3cf4847a0bfd.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1ca51be82f10026b36a89e27eee9678aede342c7.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1d0a740d8c6fe13a5357f37c11574108121f8285.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1d21e3c57e32869f64a8c21d13413dad5c92f86a.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1d3199e4362df7b57b3a0cb9ceef730d463164f7.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1d4f7f02fdfade1bd08651a418dc9ff6d830a6c4.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1d6c39f2de55ec4c5b9d3206860f0db0cea467a2.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1d7021bb0c4320818f8504ab5c2c5a1184701ef8.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1dc1980679b1acd0b843b77b880ec8b09a17b196.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1dd204e0876a8647e23424673d618fbd6588b00b.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1dfa64830b447565c2ace6d739b499fc4547c5c5.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1e2de918bd70d20976a0e8a98d190088701646c4.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1e837efd315a932186a5b9c6837931c00640dd41.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1ef1330cabf1d4fbc1cf27a4b5d3ca22f1fa4a40.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1f008c424b1123585c8214967ee3f982523359dc.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1f0c9125efe5d3e660e26df0f6fa3508ba878d16.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1f2dcd6824e180db3af9e6c925dd9a717a889c01.jpg
#   inflating: Apparel_Dataset/Test Data/pants/1f50141cb9567935ad7b0a8a9649f22276f1623b.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2a14ba39178b1d7fd1086cd8a253ecf7d9e6922e.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2a9b60018512f387b0b9a997998932fd1f090608.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2ac10b8e2d74bffbd40db10c6612552f239cf850.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2ae8b907c204f82b0330c4c174d967c8c6694417.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2b59149b6d150d8dbee7b51c31ec1298fa46e2f6.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2c056f41b58602af20083e686386cd798a59f5d5.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2c164ae752497967f92d6ec9dc89916294dba428.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2c1d748bcb235370e398fdd2f9f12a446d2ca678.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2cd2696ed103ca84e25ab3e96ee8149b453b60e2.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2cf56244c8c95df9a6677cea34162346ed7f5946.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2d49d84b594f9d8c5b3577cf1627419d283f6978.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2d91bc2cf5278c12f4394ace8170490cca6a883c.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2dc11dda69d6c5ad45cd9ed81035661a5a396894.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2dfa93af84a67c1fcdeaf5ba616640a81faf1510.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2e74c3e969bb606211277913a2e3f90e19b29031.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2f238e5dea2778da471a600e2d1cec7cd60f813b.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2f33e0ba52a8c156044b5b0989fa089583919ed3.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2f40e4fad5e140ea10aa6004dd41ed20ea778acc.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2fae13c80e4d3561abbdf8502391c937f28a5859.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2ffdf2ab2bc83016f0a28614fa1ea1e3c058b46f.jpg
#   inflating: Apparel_Dataset/Test Data/pants/2ffefc61a5be93d3f48f550f64beb9b88acaa6ab.jpg
#   inflating: Apparel_Dataset/Test Data/pants/3a06c3147f769af1080372c67827da7b1ee8e1d1.jpg
#   inflating: Apparel_Dataset/Test Data/pants/3a26535f55ece2c35ba75237c2d8004e0283a084.jpg
#   inflating: Apparel_Dataset/Test Data/pants/3ad0327758d94504641ebb9d86939cd6d441d575.jpg
#   inflating: Apparel_Dataset/Test Data/pants/3b9e8efbb529cca8908e2e7624e57677a26c4046.jpg
#   inflating: Apparel_Dataset/Test Data/pants/3ba7e061c08ee1b2599d00606ea59eeda4061777.jpg
#   inflating: Apparel_Dataset/Test Data/pants/3be11b5b991aa13dab4cb63fc9b2cb158eba0c6f.jpg
#   inflating: Apparel_Dataset/Test Data/pants/3c0f17985c621b6cc9a73c42975d469e243e8cea.jpg
#   inflating: Apparel_Dataset/Test Data/pants/3cdc2f49cea4ebf446b680b23f9289aa21e63661.jpg
#   inflating: Apparel_Dataset/Test Data/pants/3cfd60aa6be30c2d8b95d650375890b3abcd8077.jpg
#   inflating: Apparel_Dataset/Test Data/pants/3d20fcfd878d40bcd30d190b543ff729ada0fb79.jpg
#   inflating: Apparel_Dataset/Test Data/pants/3d7c0506cdb92031c46584bd14c4806838126509.jpg
#   inflating: Apparel_Dataset/Test Data/pants/3db9c6e964384944f7501da665ac1b19b27b42ee.jpg
#   inflating: Apparel_Dataset/Test Data/pants/3dc8694e8e3aa8c2caa551c908c4ded2e53e4e77.jpg
#   inflating: Apparel_Dataset/Test Data/pants/3de869e02dd8ace486a929ca860e447cca1389a5.jpg
#   inflating: Apparel_Dataset/Test Data/pants/3e2420bf890843d5fbfbc6bc2f187350cd44dd4a.jpg
#   inflating: Apparel_Dataset/Test Data/pants/3f3f2eee6e8b491673979ff3c35751d414b4fc29.jpg
#   inflating: Apparel_Dataset/Test Data/pants/3f576dea102d89c37e9c8b0c37d3a2c2efc03e5b.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4a0388c5763a5b214a7e89589f087fad0656b590.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4a0dacabaa9776fe3cb5a625679c5e2ecdea4162.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4ad4062aec1bf917083991e534bc3892f80b51e0.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4aeeccfbf5dc45ab99d46f375dd5edc27057b67e.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4b256bdfa65073ad83c21f9f142ee8e5088a3629.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4b2ceb6d0e45fb9c939e9ea6117a4b7ff5668744.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4b35cf6556554c366411b3859d99de029417bf0f.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4b74e829ac4faa0267883150926e5c4dd19a2345.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4bd492c41440b7fc169989984324df79ec8e2f5c.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4c2c2a73d9b135731c6358156164fd5c6e0363f7.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4c4623cbbb5919bb76a17b67a2ca4630d0a21281.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4d02ab71d87e11c7409c5102bd200fcad32ed02e.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4d1faa8549db7a964031876de500a890fa6ade78.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4d69b74039143f3fec5fc04e30e518d4a4d2f0b7.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4dc2d312d33cc1fb570916b8312df5a175a7111e.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4e06d7688f4899c34f43e3668f8d359889c21d0c.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4e2b9e6e3782ebba80f7ce781773285a71e077fd.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4e7af2f6ff31655235aba4abd3576559445a003e.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4e8a4203fa4bb4ddddc8c2047e2c13f5f284036b.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4e928e8090d8612ffd44cb8268fff9b5deacece6.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4ebea69b4bb64e56c5705b8461bffe2023657eae.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4f7d0dc26b298439404bd85acb531de2db09d148.jpg
#   inflating: Apparel_Dataset/Test Data/pants/4fd39a152676a78fec99a0c4a89c2c72257a2c85.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5a69cc607cacc646db02451b4eaad3fc719ed63a.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5ab68f575a4b121bfdb50aae1c2a72c1a26c0774.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5abf7d62fc3f0bb6baab61d05168187f2a8fb83e.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5b083a2d8fd209c9684349433058a4449a88d3d3.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5b2746b731607562c9c3a17783e6eb373ae73269.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5b542647a1b31294e4f512cdc22d5be42d1dd345.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5b6528b503d4e883050d912e30cdda644275ae7d.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5b892ef1739f2cad89f99124ec04249a2bc39b6e.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5ba0d5578ee90fd643814f2146eacf1c0b5aa114.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5bb6bae143ef1bbb05ee26adc098834f54d1e59f.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5bbf55e699cea6964bffaaf7fb9d31925d3de1f2.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5c067ede0eb695922597c458db84d79d7e3b8233.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5c3e5cb142bf61aaed8fc01bd23fd1712cce8973.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5ceca7ccf205000b9e91584ba60d288cd6741e64.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5d267055cdec48cb449e686f723a8240625c1765.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5d5e339cd3c1580fb94190eb777ec7b0b37cc7a9.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5d7cf4dc0dee9e7686c403ef0bdd77eafe0b8b02.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5dcdf79cfa4e6508d2a093856eaade5458ce6531.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5dde37fa4097b9fb2317a13816030cab751df40c.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5e0424c211965e27ea03e5033a77117b08e70c73.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5eb5737e860684d5e927a027d89772c220cb65a9.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5ebedfdb517dec0393566b9ec5425215cdd81c83.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5f0309b1e91d958e087f52fc8607912f7d55c572.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5f990c758075f2cc2ac943b5090621546879a2f7.jpg
#   inflating: Apparel_Dataset/Test Data/pants/5fbc8dc176b7394ace4558fde9325cfe688cd5e1.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6a2ccebdb4850197523a68106f2cad2752030a92.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6a6f3e945ec59566de8326ad3410d7e5a9efd3cd.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6a8f83e7914eee25917ab8391888009309a10bdc.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6aa0851b2728e656db109cf7086aa644869c3dc6.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6abd9b882bbf0b841d21ce0676929e73a6a66345.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6acb562fe60be0be20ac9e0f2fec017d46966ba3.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6b04248d7a6bea3a4f3c5c5ce721db55eed2c5c0.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6b400ed0bba82115ea1edfae7096be7f345246ba.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6b636495b498dac17b28a6fb2bc1996729b63b45.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6bacbfe1f9910663b9369bea64e6cecd6341cde8.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6bc867b35e2f2d25f4da4cf1dd0b174920548e8e.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6bd1acbc90c7b3809a86801cbbcee14c5d5a7000.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6bd9e9d20d1cb92434335da31664a842967b04a6.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6bde51fd0052e04bfddcebd1d64fb888fa429303.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6c1baebc24548e6bfc277ad430aeab6c5cf58c0f.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6c3c17a184ec1a407a0ff5b82319ef72ca5f38cb.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6cbdcee3572cc17eeb3ce5ce81a207f36d9e3dec.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6d0527b451bf8eb2dcada355a2112575d2cf16c6.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6d233a3fbc653e99e71126e968198cb745b780df.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6d9f84db281679931addaadf704ebc43a6234959.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6e17103ccd600dacfe2e7eb2b3f6b2c285acc242.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6e2dc93eb9d0519cbcc6b26b57db2d0feb3c3750.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6e4350022f95a80a8de36aa4d6f858cd43b0d70b.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6e524df4b1751518c5264dbe85ee8379c29959fc.jpg
#   inflating: Apparel_Dataset/Test Data/pants/6e9cd338d565a525d600ec001fbc142f406c58a6.jpg
#    creating: Apparel_Dataset/Test Data/shirts/
#   inflating: Apparel_Dataset/Test Data/shirts/02d41bf22fffbc17fc0d9bf25e7cdc73afaf06e7.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/02ea58411e0bd3bd97c8b43fac82804dc64f0074.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/03d17c12f8f13ebc5fcc058bffd9b9a7e21f4522.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/03e9f873445987e6adaf0d276e1cc1c4d0e82a16.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/06f6d09f0b557770ae396a7dbc5a74d202928448.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/07a417d7efd66d2279d329ce78c20819539bf77f.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/08abbbe7bf6e8a1d1c4003204247f0bb608aa719.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/08e7cb3a05cc21ef26180bac7f9b932bf7689289.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/0a355f77cc79257fcd762da1707c5f45910c3aa1.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/0a4ed000d20e1f1ccc7effd23fa659dbda0e38a3.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/0a693b5599ea06151d166001addc9bb5f649ab5e.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/0a8d28864a24717611a7bb284ad4e439e35eae0d.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/0b7a42c6e67a45f5dd4a4a3d288ee21767959d22.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/0b8c29c510f067a0b5f6d173dfb64dd66d1c4880.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/0bca1ec337184bef24b5f30c7e7c28839d146acf.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/0bef4652f7e9d0b01207b9f6d54334f44f93856f.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/0cb07b7a18d7ab23442c28ac1b54755d3fa68596.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/0d58b3626de00fce7f4f5e24bdaf42082ab6f3d5.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/0e02f638c0fbc023d4c863638183ddbc89dc110b.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/0e78a35fe365e5b84e2a59461985d00754bfe3e6.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/0e7d9372ba311fb428f240c17d6815acc8ca603c.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/0f043e81fa6be175606b071b825ec0a8b812b502.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/0f837896ef5f888458ed93ee3808c172d194d138.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/0ffd4d2e98e3141cad89970dd1be3db031e9b9a9.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/1a5c9dc36725668a6cb4ab6deddf5f0228596b61.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/1be519711b265318b0a28067919283cf71e5c8a5.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/1c7c848803b8d344cc1f12a80879f7d4c92153a8.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/1cac244e2a73d3d396c2204b958ec6b0192d24ee.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/1d4e33bf8212de54319fd772aecfaf1f76a3e13f.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/1dd9513231bcb798c5f9da82419ce45821bde7ae.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/1dfd073adf073574c9e385a059de7ee4f62e056c.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/1ea60a4f41a0a98383ef7243e11c9479b76bd160.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/1ef1df640c4809007b08a988836c2c9aaea88a62.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/1f18bf6c50d140dee644db0f9ceb07bbb012b072.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/1fc373eabfb99830b5a186a82d092cea216ad4ef.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/1fdc14b343d097993496fc253a5282e47b5585fc.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2a0b9331910195d68fe82da97effbe43aba948ae.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2a2294c231cdebe853a3e7ca7d825db57b2f03ad.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2a5747235a426d6062d8bd036bf1b2534dd4414f.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2a756fd7af2d9d7673581b80a76db69e4802527d.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2aa29877c6133b14864b21cb4da3eca5f15e05b0.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2aa8012930ae9900d9b7d737b95457ebc9c4a16b.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2b3c97340c13a33f4573e24abd5adcef9c98cfc1.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2b866ff3bc18feafafaaddb41f8fc099199fc0d1.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2b96ebf59ae5a45284790da17a6b4c8a669d7623.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2bbe260d7197a4f288e8399c8a11c80a5f70d163.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2bd3bb6bb65582b31811c57709abfad0a049f83d.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2bd5e2a5bd858de385d69cb7045ba31b909b704a.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2c10c7a864f06a9a068c049afc6f499e572e24cf.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2c8aa06b414a52e3e1b3b7f0cb8bfd8a07a1fd45.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2cc7af7f99d7fe97587fe1da506ddcc791ff37e8.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2cd5aa6a74caf7b4c992166cbd202c943c808d00.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2cdd7bc47d5676227fad9c03fd8ddcef9a472fc2.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2ce122082c80fa440828e9e8cabf1b311b78ba64.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2d6f885646c6ab44268d901c5c1949224820ac5c.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2d9c4f99609d0381f337e48eb561651f78563d1b.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2dc01f8c1093c9fff0efc910d7a71c38293ed38e.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2e072cb9fcd61a1d1dc8dbdbee34783c81233712.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2e535a6c13aa3fb5da9726513682e2105503548c.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2e726ff9c7dbd077a9848eba1dffb81b3771397c.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2e8a1aaf28d4f152b9e06b23fd6db01b30f2a795.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2f4174650e2c7b666383545d10c43ae44977b525.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2fa1a823ffa74d4487b39c87c0a1320f7cb8d66b.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/2fe73aa62a9900fef448ce557322a4e4d54c3b9f.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3a18b6e449ea071fffe5de856f95922fb6029fef.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3a818b9b4ea895e91e89ea1c07f35fa9869872e9.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3aef6b95547640b102c0ee76e65dff2b381338c4.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3b2602ad728e34f8cb5db0a2071a360bc0feb068.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3b57fa5a88486e8b7fba59e9112c29c36c5bf83c.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3b640787487b520a07d727acbe609845f5f68cfe.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3b8afdf0d1f0ff0d92b97d4f804c5b4fbb9696fa.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3c0bd06ee99043088e20e3b2ef02b481b84bdb56.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3c176b1a7ce52ef37ac8a26ee5405972cbe04b2e.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3c1f37bc0f70cf46b4583e13a019ffdb4b708e91.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3c6bbd56078709cd4c62fef52b6219f5bbaaad61.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3ca38eedefaed93b7c4f760e6e9883dd5a775c61.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3cdf078ddcdcd51823c5679f9dd61d3f8b50370a.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3d92460d321516d865367d8f9e754f89501cd74b.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3d9b419191ab514f73448d6cbd829a3210b6b3ce.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3de83f4350f92a60018bbe279582cb66ddf0ac01.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3e202acf52f86495392f05f213a9a03dbdde7aa6.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3e33775288ce2a2c91a218f2da9d1145a96a8292.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3f07cc469623513a684dbb713d96b659b0674075.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3f0f60544a1e9daf0b8160a73e96a8a37e9502b0.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3f4c7e780485d431016975caac295bac9d713751.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3f87e49fa40f46b7aa99fbe4c6fa07e114061d9a.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/3fc4c750c786569285ddb05df3b34f3cf791bc48.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/4a96992943b6dfaff6d2275524bd35b241b517b9.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/4adc81704b30dced380c9bbd03f7fe0774768469.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/4b320f93db3da657ca8221cd93c0fa720f0f848a.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/4bb6c963567d8efd0a50fd9d01942ce635ff75e0.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/4c19285330fa895fb8dc26f973cd7d61e225ccab.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/4c74b795a9a3e63057e5c51d6d1ca35a435005e2.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/4d2450cba682c713c179606c9489debe05f68fe3.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/4d59ba4c506fbf0f426349cc9c34da302eac3b25.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/4e07d4a9ebc1b8bd64ad20bb7936ee627f333f84.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/4e2625678b54adc24642bdad8043a03a423fe924.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/4fa0672c9976ab4060a1781005f3ef76477e14a4.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/4fd2e343ebd325e42f55aaf088c715b10fe87194.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5a042e76a15865ab327552b595f1471440e88e23.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5a31997b4babee18d10c9fa9b1b88a6daf05f471.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5a47a0775b01a7306e798a4fd7b4bdb10ec79485.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5ab30657615cab55dbfc5f34a6bd9918d14c3d13.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5ab44f2e346c48955bc56b6dafdc57522f823f00.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5ab7a20d85a0d7d2a8d620d44339aa4c122c5e60.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5b4494a7503f81411985c08583736631b4384121.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5b50030f77565a646ed4ede505eefa12dcfe63cc.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5c26ecb35624d7eac7b9caf2c8c7ff226e3f254e.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5d576bf46e135c120a56ab4b80dc12ae5171638b.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5dc099f95c0e6efda421b004d68d49055810df52.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5e2b7342f84b91a04333bcb670e89e8bd2ec3cdb.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5e7b267fc2b1643c7c5025d3f8094c35ecbf3828.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5e8f02902d697b76772bf63be90f1eae5f6b2f64.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5ea19328ac58f58b831f90b54f8b5cbbe4e13bf9.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5ed9c1ba96ef543eb999c84304c3c5d5341eed18.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5ee5a43da6b510e836d7f505d196d0715f918611.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/5f14da0d5e79586fd3a55860193e6132d53642d0.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/6a7063f0409249879c1dc812363365b79aededd4.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/6a976c797b01e66545dfb09af11170b094708235.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/6aa6c97a68b318c126a16c9676350dbad884d2d4.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/6b341369e89e673edee461ca92b656f3e1b0f09e.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/6b4255f77be5db6f69ac74b820a8f437d4eb8ae7.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/6bb810f4799283e777006eacbb2ccca422fe128e.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/6bd04cf5847ca30952963f06397b334f96317c0b.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/6bead0ecab6d0fe7ebd4aeb9fa6784332d1573e9.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/6c87c51358bd0bcb4b081a94d761ab2cedafd89e.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/6d604abc98a0413580ceaa6c7b4ba3a5345b7251.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/6e245e25a496317ef33faf7a19a51126100bb227.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/6f44d1589917108d080908fb7c9882b0dd02cafd.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/6f6b1159044b55c0668d0d68995086028f07934f.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/6f97b07579657d04185c5d9a18fef84878cfe4ef.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/7a2d92e2d70ee7196e72ed57ab4bb7affc5e888a.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/7a7b7b88dadeeeb1b51d2fad4d622ca3a8aba80d.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/7b9752cb0433587f6c59c5fac810974a81c94f7a.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/7c96fb7fa617125a11d369f6db98a47065e72232.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/7cb32732d44929342da03577c7152faf3a064ba1.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/7d76f240fc55fd499b8aa7e7481d1a9407fb233c.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/7d76f7b988c2b41ccf16a0a28a9908e032bf4c4b.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/7f9d5d3ce2dd9089565bd04f71259e22309694ad.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/8a006b537cffb16bbf83cfc7034b86e248260d6e.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/8a0ddb2d0d53844a033dbcd0f899c6f223155535.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/8b1de3ec0e756859ff45782bfde75e8d4943dc69.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/8c01d2e3d5191ee61d86889d4bc59ea76a55649d.jpg
#   inflating: Apparel_Dataset/Test Data/shirts/8c8cfbad74ce07beed5083c3ba1e24534937bd9d.jpg
#    creating: Apparel_Dataset/Test Data/shoes/
#   inflating: Apparel_Dataset/Test Data/shoes/00011ef8f01769a1eea4e8fd4c6a445608de061d.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/04f78f68ad64d04505c32aa0540aef2bb7a61bd0.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/05a24d0a20d871d8a040c4a53d719c54151fc42f.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/05a6a402c7279d56fe7372021ed92d8fddcd1831.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/08bbfde61bf2922ae0a00219e0421b59eb43e390.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/10bbe8934e7ad6a734abbb8f7c290ef818aba1e0.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/2bc70a53196d8275b5f4e1fb36a66194318be318.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/2c41ce115da2ffc5b99dcb9907627748417372b4.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/2ccd800e3834e2d96a09febb04e5b49f15dd4dbe.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/2e481efc88027a583786b5862ffe286771425003.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/2e652a968c2ee070c005f4d03050304aa1cb920a.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/2e74553be455d91eb8b723b0b522fb9c9fcd9552.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/2f43b3e26f259b8af31132b94c24616ded5a1227.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/2f43c5079233bd0bbcbdbcda6bace9f1e154b979.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/2fdc6c371111205b76b3fdc7a6efe9e841f5118b.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/2fea042028acf6707688b9f6d12b43651ef71663.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3a0eccb519ecbabc6ddc9166106e9cc3548e79a7.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3a1bb2d6197547038bd7b596133d15f1f0669e5b.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3a24a1b28571b74adb87fd35ad570af6ed401794.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3a34ab86819106f84752f27238dd7f2ac9b1c7da.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3abb402bbd7fe546828a04a00bd3ebe44646ab7f.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3ad34e2f2fcb37e15d9fb10e6895a0d1d969bc90.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3b0b2aad9e2640fa17c0720725fa316ef1125b23.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3b2f907f6aaf3e0e1be39b0fca4f01219b13d52c.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3b6e5d1788e81e3872274a203b6fb1db4010acfa.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3ba24ebb76f1b95e71d4b5c3545e11b628ebedd2.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3c1220a68d55afd21b27185c31ca918484a8a816.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3c5da906572b8f0bcfca28ad9da4bfca4ec94a87.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3ce010de4a0f9a13f6241eab741fa361237a0d68.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3d05c0bac3f0ee8dbcd043c154b820aae6bfb11d.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3d06c3265d0e9bfed103db9fcd25e47d38edc3ad.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3d0e7502df28f323be1805d5ae501e01cc021875.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3d61829cea0c7641656420e4befc98797a55e0c7.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3d771cea348edf1e58647e9b58a34df7fb967749.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3d8b87b8df613704cd0e46a1815cc80814dccad7.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3d994bf42ac870e81ebbcec55765ed17f24fa84a.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3dcb8547716c8743abfccca288e1eb6af4b85b25.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3de31cc3d98c873df08b64b8cbba2ae97f8e49ac.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3df003fa2c37a43009c94d93ba0c74450f744b69.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3e2ee472a82c1ab388c55aa064259da27dc6a5db.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3e33e2ca1b991488cdf3864d8b89e476489ca45e.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3e3eb1fe468ec0bd58cd953b8784424145ba099b.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3f6690033ae950ab53265b13f04598ab1b8635a0.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/3fe492344bc9289b9b54ffce3b546a9d3b073591.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4a1bcc6dd2ac4e71eba0abc55123d88966e29fb5.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4a2a7e0ced3e9462df02989c2ce8111e3221715e.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4a34feb2ee27a0b63fca135f7d551db96e736840.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4a4ab186bca37774411c7d30839d4b429d10dfe1.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4afeef5955553abb789b163fabf1426df5c372f5.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4b7d748c6ed17e0e55ca797c6efedf48eab7de5a.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4b87b3ddbcc584da00bdd028fc4ad57f6c63e001.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4c56054b2dd070c83e895244dfe94fa5894fb385.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4c683f983d4b3ce95cb73a91a45d2d9ff3ad9bd4.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4c9adc1a2b148915ebebbc31fd4571acf8c0bd89.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4cb0c87767058257670a04273e2388030973404c.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4cc82981f2831864198e2e807b526089d8bc43ed.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4d0baf34fc35d7655f8ddc282d5057142c130690.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4d906d30ddbce4786f8755a69b05115bd579aa10.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4e7ebc85161d847aa6c6448dd7c3f54e5dcedde9.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4ec146dc2fbc05fd3caaf76f3c94ec6476375f75.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4ed8a581511e00453e6200b72c899127ac7c1065.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4efc3543270cf5e429be620db7f94596f5a3e69d.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4f0ccdcc5fbafbb721a645549b8f73b822c70389.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/4f38e0e4b208ceef7e2346b716a179dced15d4f3.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/5a9c174a3bc971b5344a392fb391090244caf51e.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/5b8821774e8f8bcd2d39c0a46088781661f85e16.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/5c17000c7b5df04b72d04e82e868eafce28073f2.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/5c2a9970910c1383007b143f4cfd4d6a4fa9282d.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/5c5c7bf950c2fdbe9b13f7e045e5a629e18ccd97.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/5d1f8d79d1bad3f8ae9a4529447207d0fc86d93d.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/5d480916cd770f2281216f90f3f9db216e2e915b.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/5da63806edb908595f1fd7b822bab5e6057e1262.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/5e8ff0d23219537ad50fd4ff43fba2fec39e34c4.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/5f62ef6adf0111d2da9d4e481ef56cabf74b058f.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/5f683e1ea26ad9cebddbd1e8998c9a903965779e.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/5f9f3e89e5231597b0c220108f7d6f585070a1de.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6a035cb55db883b205c636935aaa557726612b2d.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6a1396619bcafdb14ac778a6f8105f96fc7d5772.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6a426bfb9142efcfb1e130d1cf1d529ee359ea9a.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6a524a35775b3c20d9348bec468e21506daa9fe9.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6a878f90452eba329dca140d1eccb775d2a2912b.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6a9e7e13be3e1f8adb1fd113c3275989eb806bfc.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6be881f76086dc87e8c3ef63bb1f92dc4f7e6831.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6cc3789ddb7de4da2d8bf3d7266d6b8b467af1fd.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6d7d5180caef3022c13e96d6e8d29cfc497369c5.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6d9a3644635f37ad699a64ec57405d2ccae4cd97.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6d9b4ae3bd3c1fcfa4e499198f06c907f4f830f4.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6db48b0c49234470009ddb34c40d0f456348b01d.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6de5b70c46fc494be6aa00557be9c2c1258811fb.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6f03d054d6730672cebc593e6ea88adf3e181935.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6f158c9c516a48afc7043681c25b412d3aa9c0c3.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6f1805f65d347b157ed410acf92395827d7f0519.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6f94307c1153e88bffa332cd59b521ce73688031.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6f9963a15fbf7160735a55e916059bf053251a67.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/6fd7a0b7c9a1a40d204f0e242391fcb480cfdd93.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/7a0c144592c34e1840b9cc8cb0c1bc788e31e786.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/7a1712a3eb16bc4bd1e3a4b177cd8e64f7af97b4.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/7a4ec07e7a58c27604741ac7b8a736040c1e44e5.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/7a771f44a7abcfb700033809269352ddd37b97c8.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/7b2cddf90ed525a60a4da43f360f22e1150c4314.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/7bcd966f1eefee5b25ab98de2bd181bf7d5a4af5.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/7c5d173c38bb32eafc6bc643fa7dca37df44d008.jpg
#   inflating: Apparel_Dataset/Test Data/shoes/7d1713f9701ae47ecde493135b6a904d0f458546.jpg
# ...
#   inflating: Apparel_Dataset/Train Data/shoes/c69c592513612689cbde18da7020d0299e320e2b.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/c6fdd11b3b9b0524f131c2cc249e52e798cd5ab3.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/c962b1e35b34713763bdd16d789478de4bbd7b00.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/c99487bf511a23974e88f67f0d2a3c550f34c849.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/c9b706eca98ff60e33808efa1157baffb5032403.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ca97f4c22085b08eaf6b1b24f964b6ea3f81d4db.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/cb45f6199d496ded21b4a63cd793ad904c902f97.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/cba9f67508c8925f07dc63344095fb28d236ab48.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/cc3009c9975848d6fdd9b888eb5ea0462fa0b8b3.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/cc85c2f14af53978d340b50ed2cbf283e8ebfabb.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/cd1735bdb78b0ee33f4e46b6f03f3ee94b12f15f.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/cd19442ab743ad42d4d15b44c5e298bc9bbc48e7.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/cd4ebb35a9edd105d07db8557e59eb7e2795b898.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/cd5fc60920c9b7665a85250da5b0b438c787b861.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/cd62ea6ab994b48b782859a7c1d81b361a52e7a0.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/cd67cd1d762212d25d1efe47cf1b5f1bfcb53b7f.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/cdddb583200a82440a4b7e498e8c7079b3e62a8d.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/cde1bd2f5182a13dc85aae51cebacdb54acd9a09.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ce1356603b49df019756c5e34e13e3492fc9127a.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ce84125731ae0fec9fcc616b930705b1e17ef8b6.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/cec345a3af823e0312e2bdd723f8e867bcdc5adf.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/cf01e2002b441c1e66795d6806b94c86c3c84229.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/cf5c355e2c1b7fc31f869ce5b32b49337b612dd4.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/cf5cbcc9349b9b2c6ac34dfb4724f56006d666c0.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d0306d6e43b939212618b31178a373afb60988cf.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d1029eca1a527d8623fa2da70bfad28aef437a01.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d113624fe43f5c87cd969a8bd1f2a8d07db2457f.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d1533463fc2d4c9535a9fe90e6bc690348556fba.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d18ff898a9309da3d732bd3107ffa0ad9cbf633d.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d1a5930a7644f7ff0519d1f65feda10359ea9aa5.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d1fb6cd51255020feb904ccfd9bf689b184b2096.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d216f8e1208f4bad6ee4dfc9e48d619e4bcfb73c.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d27015a514c35aaae72377d3a8f04ed8345a2088.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d2e1d8d7a7648262c9ea925df1dd040e175c66c6.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d38e09f057ffa83242d823853fbac18f43d1e3c5.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d4c06cd511edfc85764f5a3c4c6a01095b83dedc.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d50934fbde9b1af5c4ccb2ad0c0e5a37271a2c0a.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d50cccac641067533a6f9bdde363ec0110dc0402.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d5b45176453cd4a00813e5ffbed4fe09162fdec2.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d5c1e942b668c2ee0e6a189705b5de02d9501228.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d5c4e38b8cd809931b45ba462a6a51b2a82572e9.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d74753db63e509f81bb18e62051ef989a41ee7c3.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d7f54b9467f47777521080546ae178f0d996db40.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/d8459724b1ae92eac06bcc40c757ef1fd9129eed.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/da5d3617e3c01bc27f71a0d935ee8da7a2bf74ec.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/da67946738ddec097db5e05818115fcfb8c60b82.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/dab114724b09cde1ddd6237c4d0fd0a4bcd53187.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/dabb2b71585c95c1ef42df337f62b6ad4f3cfcfa.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/db6f899a2d9d61ba033ed307d7e7d5e9890a999b.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/db74dfacb4a985a6999d6cf96372e5a32efb8ba7.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/db96aa0e20e86893e52d3b79b471ab1e9a641a43.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/dbb0889e6f367b09bf14d595783818ca1fd33a3c.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/dc75d0413101832be18ef55f5311492620759816.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/dc95d901dee0b0b6f7b98fe78049a0f78fb775af.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/dc9609a121376a6bdea0007a52b5cb7a928c41dc.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/dcd7dddc77ebe687f1df7c04f0be78649aa5d1b1.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/dcf9eda01e7e581c20617a624aac19c0e670361c.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/dd126aaf1ff624bf40dbd4c501ecf4df74fdd46b.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/dd44cba7dc940457c67bdf0cf271940f2ff57518.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/dd9621d0d21711b4de918a8f289e0a37f8014f8c.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/de04fa87dda026260e6b4fb6189eca46a4ebce79.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/de2114beb803b7417aeb7b1c8a67f1a428679e59.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/de255bf8a458057d64cb2d376e80c7a4eca816be.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/de970ef3c806e1201b256181afacf9eacd13dde9.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/de9dc364cd29d428199792b1a80778e1123d7ead.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/deb991bb316706f2faf6bf847730a2fca7180ee8.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/dec872ca4cb4dca37ee10f945e3fc3367b35ac56.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/decf7661a12e958cded89f30ea165e9516b7bfa3.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/df28ad5293b0e840e5d51e89a52090867bd580ee.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/df94aa3f8368d7ef3b7f71b945163b2d6bf1d47a.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e05df4c4917317d63e35434c96fcf338c49ad97d.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e0ad3eb2b8f2480b74e87eb5e87d129747057604.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e1000fb82c4b88084463f7358c014fc4f70923c9.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e1ac26c3e4170b7df6ca7adf0bf0db16be49cd7c.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e2d5c216a22d93555f3a2ebde9ba5a4ebb5a420f.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e3685455c3b30858f8d848622cb05f27a976d907.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e36e39bca769a6f3c15eeb186ac78a44e6fe1092.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e3c7c59f7665d91cf3e9a02b37e3d303cff33184.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e40a6bf898a15c0c5bad31b91fd1b87c7b337a10.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e40d8d84f0873dde4d18d918207b00e2d268113f.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e4268919499921a3b4de118751d672edb5666018.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e44a34f3876ea344204061bcae3de014b15a8ea7.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e47bb384288fefbc59105cd7d314485c65b39026.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e4a8bb7b61304d98b3bb66cb5ce507d47cfee848.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e4deea95c7f0b46f5c8069c1c4cb8dc0cb9dfab8.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e4e3d85b4d4626b65ce95b617a4cc20d3fb4a7d3.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e526586b33548b29d1c241e1d8a7cabf290d5dea.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e56a42a1eba779f55bbb999ce20a7ff75b102be5.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e59017c596f6d4b9e0b313557c1c2746a2f326c3.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e5ecc8de1d3257e3807ffc1161f860684e1151cf.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e6234820e1a6994fe10f9593932e1ddb6e4fd7d9.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e640fdf947c0226b294f59c3560620d62be0b3b6.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e69e117bcbd7cfb4bd23baf2150f391b0d5b85b0.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e6c71a554a7a83f1ca7fbedb37c8cd73a2a22eaf.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e6d6470261bf3bc5f850099a3da2c9790e85a8ef.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e774bb0728d4f5d39273b18462590bcca55db8c6.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e779c49b605c6c5c67fd478a2263511a41da0b6f.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e7c1e05db1a6689256161bfec2193e6ccda31023.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e7d72d396602112962af483b6f113abb13dd93f1.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e7fe407966f8c761edca27fb0c5545697ea73a59.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e852c0bea21a1547910a1f82320eb6be94c85cfd.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e876492c94316a696de79560aedd31f5dc8a6ce9.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e96e1a159ec4fa7123241de867c1b9d142a4d882.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/e9d0170f653264b0753c65c08c9980925219b3f7.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ea0f7a52e8fb9ac03ad505c2e5677845b015144e.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ea43339d75f20e8772700534598fb90ba9293ab7.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ea86ce11c647e52ae288c42021493d0270229ba6.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/eaa69e534cb4fd29125f57abf1e9f8be12d5f8cb.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/eab1472298c832b859ecb09de08d2358046a61af.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/eab6eb0400ce4e919dc22cdadcbc9daf6818bbe5.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/eaf569daadd290dbbe703f1bd804c73646a9cc72.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/eb341042472797278276276d7d65977c58081c36.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ecdd924a39ffeacba19212a4d9fdd4b5edd9f9e3.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ed0ede44c8f3cabe6f3753190ed92a97e99d59c4.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ed19a385fa8ef8dfe833b5a8bda56cefa5dbb593.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ed3b8727882b9032dcd8f5ee2a8d8881dd0503d0.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ed5595a7568d44811bf24fc19a272d22e71d29dc.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ed8835192f3761374b180cc75c87620870002f33.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/eda3d8756e1053e2281ff2165c79bfa3fefa7bdb.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/edcbfea7227e26476d734c5ee29b2fb83d249162.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ee4d170facf365974e6a3d633fd110b17052a377.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/eefb07919d9afa541002af683babd6a0c4d77a6a.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ef148d8ed750d21dca20d21a81ed5620d8ff24d9.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ef23828185e97467cce04c3d5523c673954633ff.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/efa8f568dab9ad536911c9fca63612aa5d0d530c.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f037dc64f5b48dc42aed5c90ef315a3ed1e0398f.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f04b2df08c3b8bbc4717d8991e2ec2fee45055db.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f0f96959795c7cbfb3261fe92233a20e74c10fe8.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f13da93384811735149d91c752df3a809d568a52.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f1a2f1157561b10572c4295f78042782d7a9d7d3.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f2185def9fb9abcad6a4689447e175e12c5657de.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f30855c36afc91453c4a7ff3fac80a5b94f9bf43.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f3151de000b90197719bddc5e5736573a635b797.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f37a3b91d13e272655b14aaec450fb78c006804f.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f398f0388e3decf7f6e4ada63bc04d77aeaaa33d.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f3d95ba1231686ee0b093a86d1454fb1f85ede08.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f3f666a1566577b3afe63fc27f750c8771674340.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f411b1b2fa1272104449603c343959436ebfcf09.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f4433cd8d89c830d83479f350f57e09ecc08645e.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f5adf235246f5bdc51cd1a097f73250fe1aecb3d.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f5c70e7e49325afebf2f7376ae43979a71629668.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f614319fdb1f4e887b95bd00768b79d2c649ef7c.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f61bae9127104a3f8ea1b5b201bd46fa2f9ec21c.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f668c012ff110b6121642889aa5b71d84a96540e.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f6a0500ecc7eb709bb5e9c686410a7e2f17ef477.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f6b81e6bc5362169951f16519a1ec860355dbfda.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f6d467f23ba81e701dea60611797ea3fe0c8a743.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f6dd57e8e5466f7fa488c39e17b5e16aad0113a9.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f71ccb4ef537b95f99ac93fe8037db7ab27f702b.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f75c95cc9642349daf53bc2a464c0a24775eca42.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f77e05d08c454c72dcb85056989f5dd6c8e94824.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f788cfa9ddaff7a9171896541d1ce7e4bb751229.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f86d595a1a9b87a34f8e579e344770002fb7d6c6.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f88b84d482b7f271fdb14ade2d54ead13b257e39.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f891a87b6f77d08b5c89d9047172751da8c3dd4c.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f8a1871b7b3cec14c5368bed575b1cc481022798.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f8a3e2ebaf112df5bf869dc055cd11922f7b65a6.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/f8d1cf32c3b84d415a7cd1dd0779106fbfd5be27.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/fa4d95075f6e4bddbab3855ff9ca4a2d7d2a8219.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/facd5294f0e848d18a047a2c73a16ceee4195df5.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/faf53b5350e826994b83a9f96e7102e47d0756b9.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/fbf5f94560ccf1f9741b6efe1b3de0ef449e7f77.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/fc80fdce2361f8e4de71b5a017902105d3458192.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/fcc615519220e10c80872021f4d27d443cae6d65.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/fcd2f76520dad5645c1409082081f8ff40ed3e94.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/fd46d85a5671d64fa71b97745582305e0a77b7dc.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/fdb2c0d6bbb16cc2e1e07e5277b435cf89ffb768.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/fe4b23288e00fd224ad1bc70469bbbe4ddf80be8.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/fe99db2e1b64314e384ad4e71e8c562566d4fc1b.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ff5868bc5b70e4393b11827b5adcee1a34e8d975.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ff7f558959757ab7e0ce610e278c9a7cd88d598c.jpg
#   inflating: Apparel_Dataset/Train Data/shoes/ff857aa27a8a53b8f39f786a74dc5b0a5f5d9976.jpg

# %% [markdown]
# You have been given Apparel Dataset which contains images of dress, pants, shirts and shoes. There are two top-level directories "Test Data" and "Train Data" corresponding to test set and training set respectively.  Each of these directories further contains four directories "dress", "pants", "shirts" and "shoes". The class labels of each of the
# images correspond to the directory they are contained in i.e., dress/pants/shirts/shoes. Paths of training and test data have been given to you.

# %%
test_data_path = "/content/Apparel_Dataset/Test Data"
train_data_path = "/content/Apparel_Dataset/Train Data"

# %% [markdown]
# ### TASK 1:
# Now you need to read the images and resize all of them to a fixed size (32,32). After resizing the images, flatten them to create a 1-D array and then normalize the pixel values between 0-1. This 1-D array will serve as your feature vector for the particular image.
#
# Note: You can normalize the pixel values by dividing them by 255.

# %%
### YOUR CODE HERE ###
def read_images(folder):
    images = []
    for filename in os.listdir(folder):
      img = cv2.imread(os.path.join(folder, filename))
      img = cv2.resize(img,(32,32)).flatten()
      img = img/255
      images.append(img)
    return images

# %%
### YOUR CODE HERE ###
# Reading Train images
folders = [os.path.join(train_data_path, x) for x in ('dress', 'pants', 'shirts','shoes')]
train_images= []
train_labels = []
for folder in folders:
  imgs = read_images(folder)
  for i in range(len(imgs)):
    train_images.append(imgs[i])
    train_labels.append(folder.split('/')[-1])

# %%
### YOUR CODE HERE ###
# Reading Test images
folders = [os.path.join(test_data_path, x) for x in ('dress', 'pants', 'shirts','shoes')]
test_images= []
test_labels = []
for folder in folders:
  imgs = read_images(folder)
  for i in range(len(imgs)):
    test_images.append(imgs[i])
    test_labels.append(folder.split('/')[-1])

# %% [markdown]
# ### TASK 2:
# Create your own k-Nearest Neighbors classifier function by performing following
# tasks:
#
# *   For a test data point, find its distance from all training instances.
# *   Sort the calculated distances in ascending order based on distance values.
# *   Choose k training samples with minimum distances from the test data point.
# *   Return the most frequent class of these samples. (Incase of ties, break them by backing off to k-1 values. For example, for a particular image, incase of k=4, you get two 'dress' labels and two 'pants' labels. In this case you will break tie by backing off to k=3. If tie occurs again you will keep backing off until tie is broken or you reach k=1.)
# *   Note: Your function should work with Euclidean distance as well as Manhattan
# distance. Pass the distance metric as a parameter in k-NN classifier function.
# Your function should also be general enough to work with any value of k.

# %%
def kNN_classfifier(test,train,labels,k,predict,dist_metric):
  for ii,x in enumerate(test):
    if dist_metric == 'Euclidean':
      distances = [np.linalg.norm(x-i) for i in train] #L2 NORM
    elif dist_metric == 'Manhattan':
      distances = [np.linalg.norm(x-i,ord=1) for i in train] # L1 NORM
    k_samples_indices = np.argsort(distances)[:k] # sort and return indices
    k_labels = [labels[i] for i in k_samples_indices] # find labels of k nearest neighbors
    try: most_common = mode(k_labels) # Most common by count
    except: # Incase of tie
      ii=1
      temp=k-1
      while ii==1:
        distances = [np.linalg.norm(x-i) for i in train]
        k_samples_indices = np.argsort(distances)[:temp] # sort and return indices
        k_labels = [labels[i] for i in k_samples_indices] 
        if temp!=1:
          try: 
            ii=0
            most_common = mode(k_labels)
          except:
            ii=1
            temp=temp-1 
        else: 
          most_common = k_labels[0]
          ii=0
    predict.append(most_common)
  return np.array(predict)

# %% [markdown]
# ### TASK 3:
# Write down functions which calculates the classification accuracy, macro-average precision and macro-average recall. Print the values of accuracy, precision and recall calculated on the test data for k = 3,5,7 for both Euclidean and Manhattan distance. You should expect the values of accuracy, precision and recall to be above 80.

# %%
### YOUR CODE HERE ###
dress = [x for x in test_labels if x=='dress']
pants = [x for x in test_labels if x=='pants']
shirts = [x for x in test_labels if x=='shirts']
shoes = [x for x in test_labels if x=='shoes']

# %%
#Accuracy
def accuracy(predictions,test_labels):
  return np.sum(predictions == test_labels)/len(test_labels)

# Macro Avg recall
def macro_recall(predictions,test_labels):
  recall_dress = np.sum(predictions[0:len(dress)] == dress)/len(dress)
  recall_pants = np.sum(predictions[len(dress):len(dress)+len(pants)] == pants)/len(pants)
  recall_shirts = np.sum(predictions[len(dress)+len(pants):len(dress)+len(pants)+len(shirts)] == shirts)/len(shirts)
  recall_shoes = np.sum(predictions[len(dress)+len(pants)+len(shirts):len(predictions)] == shoes)/len(shoes)
  return (recall_dress+recall_pants+recall_shirts+recall_shoes)/4
  
# Macro Avg precision
def macro_precision(predictions,test_labels):
  pred_copy = predictions
  prec_dress = np.sum(predictions[0:len(dress)] == dress)/(list(pred_copy).count('dress'))
  prec_pants = np.sum(predictions[len(dress):len(dress)+len(pants)] == pants)/(list(pred_copy).count('pants'))
  prec_shirts = np.sum(predictions[len(dress)+len(pants):len(dress)+len(pants)+len(shirts)] == shirts)/(list(pred_copy).count('shirts'))
  prec_shoes = np.sum(predictions[len(dress)+len(pants)+len(shirts):len(predictions)] == shoes)/(list(pred_copy).count('shoes'))
  return (prec_dress+prec_pants+prec_shirts+prec_shoes)/4

# %%
k = [3,5,7]
distance_metric = ['Manhattan','Euclidean']
for i in k:
  #Manhattan
  predict = []
  predictions = kNN_classfifier(test_images,train_images,train_labels,i,predict,distance_metric[0])
  print('\033[92m' +'\033[1m'+ '\033[4m'+ ' For Manhattan and k = ' + str(i) + '\033[0m')
  print('accuracy: ' ,accuracy(predictions,test_labels))
  print('Macro_avg_recall: ' , macro_recall(predictions,test_labels))
  print('Macro_avg_Precision: ' ,macro_precision(predictions,test_labels))
  # Euclidean
  predict = []
  predictions = kNN_classfifier(test_images,train_images,train_labels,i,predict,distance_metric[1])
  print('\033[92m' +'\033[1m'+ '\033[4m'+ ' For Euclidean and k = ' + str(i) + '\033[0m')
  print('accuracy: ' ,accuracy(predictions,test_labels))
  print('Macro_avg_recall: ' , macro_recall(predictions,test_labels))
  print('Macro_avg_Precision: ' ,macro_precision(predictions,test_labels))
# Out:
#  For Manhattan and k = 3
# accuracy:  0.8571428571428571
# Macro_avg_recall:  0.8492234848484849
# Macro_avg_Precision:  0.847760300650514
#  For Euclidean and k = 3
# accuracy:  0.8482142857142857
# Macro_avg_recall:  0.8405050505050504
# Macro_avg_Precision:  0.8366470778594839
#  For Manhattan and k = 5
# accuracy:  0.85
# Macro_avg_recall:  0.841199494949495
# Macro_avg_Precision:  0.8411754493846746
#  For Euclidean and k = 5
# accuracy:  0.8625
# Macro_avg_recall:  0.8530997474747475
# Macro_avg_Precision:  0.8552582088829314
#  For Manhattan and k = 7
# accuracy:  0.8464285714285714
# Macro_avg_recall:  0.8424305555555556
# Macro_avg_Precision:  0.8384191518820246
#  For Euclidean and k = 7
# accuracy:  0.8642857142857143
# Macro_avg_recall:  0.8569886363636363
# Macro_avg_Precision:  0.8568627025177347

# %% [markdown]
# ### TASK 4:
# Run your k-NN function for the values of k = 1, 2, 3, 4, 5, 6, 7 on test data. Do this for both the Euclidean distance and the Manhattan distance for each value of k. Plot three graphs displaying following:
#
# *   k-values vs accuracy for both euclidean and manhattan distance (k-values on x-axis and accuracy values on y-axis)
# *   k-values vs macro-average precision for both euclidean and manhattan distance (k-values on x-axis and precision values on y-axis)
# * k-values vs macro-average recall for both euclidean and manhattan distance (k-values on x-axis and recall values on y-axis)
#
# All of your graphs should be properly labelled.

# %%
### YOUR CODE HERE ###
k=[1,2,3,4,5,6,7]
distance_metric = ['Manhattan','Euclidean']
accuracy_euclidean = []
accuracy_manhattan = []
macro_recall_euclidean = []
macro_recall_manhattan = []
macro_prec_euclidean = []
macro_prec_manhattan = []
for i in k:
  #Manhattan
  predict = []
  predictions = kNN_classfifier(test_images,train_images,train_labels,i,predict,distance_metric[0])
  accuracy_manhattan.append(accuracy(predictions,test_labels))
  macro_recall_manhattan.append(macro_recall(predictions,test_labels))
  macro_prec_manhattan.append(macro_precision(predictions,test_labels))
  # Euclidean
  predict = []
  predictions = kNN_classfifier(test_images,train_images,train_labels,i,predict,distance_metric[1])
  accuracy_euclidean.append(accuracy(predictions,test_labels))
  macro_recall_euclidean.append(macro_recall(predictions,test_labels))
  macro_prec_euclidean.append(macro_precision(predictions,test_labels))

# %%
plt.plot(k, accuracy_euclidean, label = "euclidean")
plt.plot(k, accuracy_manhattan, label = "manhattan")
plt.legend()
plt.xlabel('k')
plt.ylabel('accuracy')
plt.show()
plt.plot(k, macro_prec_euclidean, label = "euclidean")
plt.plot(k, macro_prec_manhattan, label = "manhattan")
plt.legend()
plt.xlabel('k')
plt.ylabel('Macro_Avg_Precision')
plt.show()
plt.plot(k, macro_recall_euclidean, label = "euclidean")
plt.plot(k, macro_recall_manhattan, label = "manhattan")
plt.legend()
plt.xlabel('k')
plt.ylabel('Macro_Avg_Recall')
plt.show()

# %% [markdown]
# # Part 2: k-NN classifier using scikit-learn

# %% [markdown]
# ### TASK 1:
# In this part you have to use scikit-learn’s k-NN implementation to train and test your
# classifier on the dataset used in Part 1. Run the k-NN classifier again for values of
# k = 1, 2, 3, 4, 5, 6, 7 using both Euclidean and Manhattan distance. Use scikit-learn to calculate the accuracy, F1 score and confusion matrix for test data. Also present the
# results as a graph with k values on x-axis and F1 score on y-axis for both distance metrics
# in a single plot.

# %%
### YOUR CODE HERE ###
k=[1,2,3,4,5,6,7]
distance_metric = ['Manhattan','Euclidean']
accuracy_euclidean = []
accuracy_manhattan = []
f1_euclidean = []
f1_manhattan = []
conf_matrix_euclidean = []
conf_matrix_manhattan = []
for i in k:
  ### Manhattan
  knn = KNeighborsClassifier(n_neighbors=i,p=1)
  knn.fit(train_images,train_labels)
  predictions = knn.predict(test_images)
  accuracy = accuracy_score(predictions,test_labels)
  accuracy_manhattan.append(accuracy)
  conf_matrix = confusion_matrix(predictions, test_labels)
  conf_matrix_manhattan.append(conf_matrix)
  f1 = f1_score(predictions,test_labels,average='macro')
  f1_manhattan.append(f1)
  print('\033[92m' +'\033[1m'+ '\033[4m'+ ' For Manhattan and k = ' + str(i) + '\033[0m')
  print('accuracy: ',accuracy)
  print('f1: ',f1)
  print('confusion_matrix: \n',conf_matrix)
    ###  Euclidean
  knn = KNeighborsClassifier(n_neighbors=i,p=2)
  knn.fit(train_images,train_labels)
  predictions = knn.predict(test_images)
  accuracy = accuracy_score(predictions,test_labels)
  accuracy_euclidean.append(accuracy)
  conf_matrix = confusion_matrix(predictions, test_labels)
  conf_matrix_euclidean.append(conf_matrix)
  f1 = f1_score(predictions,test_labels,average='macro')
  f1_euclidean.append(f1)
  print('\033[92m' +'\033[1m'+ '\033[4m'+ ' For Euclidean and k = ' + str(i) + '\033[0m')
  print('accuracy: ',accuracy)
  print('f1: ',f1)
  print('confusion_matrix: \n',conf_matrix)
# Out:
#  For Manhattan and k = 1
# accuracy:  0.8464285714285714
# f1:  0.8370405388734865
# confusion_matrix:
#  [[ 70   8   4   9]
#  [  4 155   2  11]
#  [ 10  10 133  14]
#  [  6   3   5 116]]
#  For Euclidean and k = 1
# accuracy:  0.8428571428571429
# f1:  0.8318600510163978
# confusion_matrix:
#  [[ 70   7   7  13]
#  [  5 156   1  14]
#  [ 10   5 130   7]
#  [  5   8   6 116]]
#  For Manhattan and k = 2
# accuracy:  0.8589285714285714
# f1:  0.8489502792491906
# confusion_matrix:
#  [[ 78  13   8  14]
#  [  3 159   1  13]
#  [  8   3 134  13]
#  [  1   1   1 110]]
#  For Euclidean and k = 2
# accuracy:  0.8428571428571429
# f1:  0.8332781986262869
# confusion_matrix:
#  [[ 80  15  11  21]
#  [  3 157   3  15]
#  [  5   3 128   7]
#  [  2   1   2 107]]
#  For Manhattan and k = 3
# accuracy:  0.8535714285714285
# f1:  0.8424264805874754
# confusion_matrix:
#  [[ 72   7   8  14]
#  [  4 157   1  12]
#  [ 11   8 133   8]
#  [  3   4   2 116]]
#  For Euclidean and k = 3
# accuracy:  0.85
# f1:  0.8379162791457638
# confusion_matrix:
#  [[ 72  10   7  15]
#  [  3 160   2  16]
#  [  9   3 131   6]
#  [  6   3   4 113]]
#  For Manhattan and k = 4
# accuracy:  0.8535714285714285
# f1:  0.841726686908285
# confusion_matrix:
#  [[ 73   9   9  15]
#  [  5 159   1  13]
#  [  9   5 133   9]
#  [  3   3   1 113]]
#  For Euclidean and k = 4
# accuracy:  0.8553571428571428
# f1:  0.8456669753421902
# confusion_matrix:
#  [[ 76   8   9  16]
#  [  7 161   2  16]
#  [  4   4 130   6]
#  [  3   3   3 112]]
#  For Manhattan and k = 5
# accuracy:  0.8464285714285714
# f1:  0.8348529327520838
# confusion_matrix:
#  [[ 71   8   8  14]
#  [  3 157   2  12]
#  [ 13  10 132  10]
#  [  3   1   2 114]]
#  For Euclidean and k = 5
# accuracy:  0.8678571428571429
# f1:  0.859438647800995
# confusion_matrix:
#  [[ 74   7   7   9]
#  [  7 163   2  18]
#  [  4   4 131   5]
#  [  5   2   4 118]]
#  For Manhattan and k = 6
# accuracy:  0.8446428571428571
# f1:  0.8327050927298749
# confusion_matrix:
#  [[ 71  10   8  15]
#  [  6 155   1  11]
#  [ 10   9 133  10]
#  [  3   2   2 114]]
#  For Euclidean and k = 6
# accuracy:  0.8589285714285714
# f1:  0.8491733575250173
# confusion_matrix:
#  [[ 75   8   9  14]
#  [  5 162   4  16]
#  [  5   4 128   4]
#  [  5   2   3 116]]
#  For Manhattan and k = 7
# accuracy:  0.8446428571428571
# f1:  0.8354751383311945
# confusion_matrix:
#  [[ 74  11   8  13]
#  [  5 152   1  14]
#  [  8  10 133   9]
#  [  3   3   2 114]]
#  For Euclidean and k = 7
# accuracy:  0.8607142857142858
# f1:  0.849907401339676
# confusion_matrix:
#  [[ 73   5   9  13]
#  [  5 162   1  15]
#  [  7   6 131   6]
#  [  5   3   3 116]]

# %%
plt.plot(k, f1_euclidean, label = "euclidean")
plt.plot(k, f1_manhattan, label = "manhattan")
plt.legend()
plt.xlabel('k')
plt.ylabel('F1_score')
plt.show()

# %% [markdown]
# ### TASK 2:
# For this task you have been given a synthetic dataset of 1000 samples which is divided into 6 classes. Visualization of this dataset has also been given. Now you need to find the optimum value of k for this dataset. This can be done using GridSearchCV function provided by Scikit-learn. This function allows us to check easily for multiple values of k. You need to check for the values of k between 1 and 20 and report the best value of k.

# %%
X, y = make_blobs(n_samples = 1000, n_features = 2, centers = 6, cluster_std = 2.5, random_state = 4)
plt.figure(figsize=(10,6))
plt.scatter(X[:,0], X[:,1], c=y, marker= 'o', s=50)
plt.show()

# %%
### YOUR CODE HERE ###
k_range = [i for i in range(1,21)]
param_grid = dict(n_neighbors=k_range)
grid = GridSearchCV(knn, param_grid, cv=10, scoring='accuracy',verbose=1)
grid_ = grid.fit(X, y)
print(grid.cv_results_['mean_test_score'])
print('\033[92m' +'\033[1m'+ '\033[4m'+ 'BEST K: ', grid_.best_params_['n_neighbors'])
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [0.669 0.668 0.702 0.696 0.685 0.694 0.695 0.694 0.69  0.715 0.704 0.705
#  0.706 0.715 0.707 0.704 0.703 0.707 0.709 0.71 ]
# BEST K:  10

# %%
plt.plot(k_range,grid.cv_results_['mean_test_score'])
#plt.axis([0.5, len(k_range)+0.5, 0.66, 0.73])
plt.xlabel('K')
plt.ylabel('F1_score')
plt.show()
print('OPtimal K : 10')
# Out:
# OPtimal K : 10

# %% [markdown]
# #### ***Question: Is Feature Scaling required for the KNN Algorithm? Explain with proper justification.***
#
# Ans: It is important that all features contribute equally to KNN classification. However, if some feature value dominate, this will make the algortihm less accurate. Thus, it is important that the normalisation is done to make sure all feature values contribute equally
